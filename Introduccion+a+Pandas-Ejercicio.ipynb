# %%
# importar pandas
import pandas as pd
import os

# %%
# Opcional: usa el pd.set_option() para mostrar todas las filas de un dataframe por defecto
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
os.listdir()
# Out:
# ['listas.py',
#  '.git',
#  'bestsellers+with+categories.csv',
#  'Introduccion+a+Pandas-Ejercicio.ipynb']

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
df_books = pd.read_csv('bestsellers+with+categories.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(df_books)
# Out:
#                                                   Name                              Author  User Rating  Reviews  Price  Year        Genre
# 0                        10-Day Green Smoothie Cleanse                            JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                                    11/22/63: A Novel                        Stephen King          4.6     2052     22  2011      Fiction
# 2              12 Rules for Life: An Antidote to Chaos                  Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3                               1984 (Signet Classics)                       George Orwell          4.7    21424      6  2017      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...            National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5        A Dance with Dragons (A Song of Ice and Fire)                 George R. R. Martin          4.4    12643     11  2011      Fiction
# ...

# %%
# acceder al atributo shape
df_books.shape
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
df_books.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
df_books.head()
# Out:
#                                                 Name                    Author  User Rating  Reviews  Price  Year        Genre
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                                  11/22/63: A Novel              Stephen King          4.6     2052     22  2011      Fiction
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3                             1984 (Signet Classics)             George Orwell          4.7    21424      6  2017      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
df_books.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4

# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
import numpy as np
rating = np.random.randint(1,4,550)
df_books['Critic Rating'] = rating
df_books

# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados


# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.
# Out:
#                                                   Name                              Author  User Rating  Reviews  Price  Year        Genre  Critic Rating
# 0                        10-Day Green Smoothie Cleanse                            JJ Smith          4.7    17350      8  2016  Non Fiction              1
# 1                                    11/22/63: A Novel                        Stephen King          4.6     2052     22  2011      Fiction              1
# 2              12 Rules for Life: An Antidote to Chaos                  Jordan B. Peterson          4.7    18979     15  2018  Non Fiction              3
# 3                               1984 (Signet Classics)                       George Orwell          4.7    21424      6  2017      Fiction              3
# 4    5,000 Awesome Facts (About Everything!) (Natio...            National Geographic Kids          4.8     7665     12  2019  Non Fiction              3
# ...

# %%
# mostrar 5 primeras filas
df_books.head()
# Out:
#                                                 Name                    Author  User Rating  Reviews  Price  Year        Genre  Critic Rating
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith          4.7    17350      8  2016  Non Fiction              3
# 1                                  11/22/63: A Novel              Stephen King          4.6     2052     22  2011      Fiction              1
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction              2
# 3                             1984 (Signet Classics)             George Orwell          4.7    21424      6  2017      Fiction              2
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids          4.8     7665     12  2019  Non Fiction              3

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre', 'Critic Rating'], dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe

# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
cols = list(df_books.columns)

# Quitar 'Critic Rating' de la lista actual
cols.remove('Critic Rating')

# Encontrar índice de 'User Rating'
pos = cols.index('User Rating')

# Insertar 'Critic Rating' después de 'User Rating'
cols.insert(pos + 1, 'Critic Rating')

# Reordenar el DataFrame
df_books = df_books[cols]

# %%
# mostrar 5 primeras filas
df_books.head()
# Out:
#                                                 Name                    Author  User Rating  Reviews  Price  Year        Genre  Critic Rating
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith          4.7    17350      8  2016  Non Fiction              3
# 1                                  11/22/63: A Novel              Stephen King          4.6     2052     22  2011      Fiction              1
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction              2
# 3                             1984 (Signet Classics)             George Orwell          4.7    21424      6  2017      Fiction              2
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids          4.8     7665     12  2019  Non Fiction              3

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
df_books['Average Rating'] = df_books[['User Rating', 'Critic Rating']].mean(axis=1)
print(df_books)
# Out:
#                                                   Name                              Author  User Rating  Reviews  Price  Year        Genre  Critic Rating  Average Rating
# 0                        10-Day Green Smoothie Cleanse                            JJ Smith          4.7    17350      8  2016  Non Fiction              1            2.85
# 1                                    11/22/63: A Novel                        Stephen King          4.6     2052     22  2011      Fiction              1            2.80
# 2              12 Rules for Life: An Antidote to Chaos                  Jordan B. Peterson          4.7    18979     15  2018  Non Fiction              3            3.85
# 3                               1984 (Signet Classics)                       George Orwell          4.7    21424      6  2017      Fiction              3            3.85
# ...

# %%
#usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
df_books = df_books.round(1)
df_books
# Out:
#                                                   Name                              Author  User Rating  Reviews  Price  Year        Genre  Critic Rating  Average Rating
# 0                        10-Day Green Smoothie Cleanse                            JJ Smith          4.7    17350      8  2016  Non Fiction              1             2.8
# 1                                    11/22/63: A Novel                        Stephen King          4.6     2052     22  2011      Fiction              1             2.8
# 2              12 Rules for Life: An Antidote to Chaos                  Jordan B. Peterson          4.7    18979     15  2018  Non Fiction              3             3.8
# 3                               1984 (Signet Classics)                       George Orwell          4.7    21424      6  2017      Fiction              3             3.8
# ...

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
frecuencia_relativa = df_books['Genre'].value_counts(normalize=True)
print(frecuencia_relativa)
# Out:
# Genre
# Non Fiction    0.563636
# Fiction        0.436364
# Name: proportion, dtype: float64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
df_books.rename(columns={
    'User Rating': 'UR',
    'Critic Rating': 'CR',
    'Average Rating': 'AR'
}, inplace=True)

# %%
# mostrar 5 primeras filas
df_books.head()
# Out:
#                                                 Name                    Author   UR  Reviews  Price  Year        Genre  CR   AR
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith  4.7    17350      8  2016  Non Fiction   1  2.8
# 1                                  11/22/63: A Novel              Stephen King  4.6     2052     22  2011      Fiction   1  2.8
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   3  3.8
# 3                             1984 (Signet Classics)             George Orwell  4.7    21424      6  2017      Fiction   3  3.8
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids  4.8     7665     12  2019  Non Fiction   3  3.9

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
df_books = df_books[['Name', 'Author', 'UR', 'CR', 'AR', 'Year']]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
df_books = df_books.sort_values(by=['UR', 'CR'], ascending=False)
df_books
# Out:
#                                                   Name                              Author   UR  CR   AR  Year
# 83   Dog Man: Brawl of the Wild: From the Creator o...                          Dav Pilkey  4.9   3  4.0  2018
# 146  Goodnight, Goodnight Construction Site (Hardco...                Sherri Duskey Rinker  4.9   3  4.0  2012
# 147  Goodnight, Goodnight Construction Site (Hardco...                Sherri Duskey Rinker  4.9   3  4.0  2013
# 153  Harry Potter and the Chamber of Secrets: The I...                        J.K. Rowling  4.9   3  4.0  2016
# 191  Jesus Calling: Enjoying Peace in His Presence ...                         Sarah Young  4.9   3  4.0  2015
# 219                                  Little Blue Truck                      Alice Schertle  4.9   3  4.0  2014
# 249                          Oh, the Places You'll Go!                           Dr. Seuss  4.9   3  4.0  2016
# ...
